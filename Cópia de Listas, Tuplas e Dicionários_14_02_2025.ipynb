# %% [markdown]
# #Listas, Tuplas e Dicionários

# %%
#Lista
[1,33,12,14,21]
# Out:
# [1, 33, 12, 14, 21]

# %%
#tupla
(1,22,5,32,6)
# Out:
# (1, 22, 5, 32, 6)

# %%
#dicionario
{"num 1": 2, "num 2": 3, "num 3": 7}

# %% [markdown]
# ##* Lista exemplos

# %%
lista=[12,"pachevo", 1.55]

# %%
type(lista)
# Out:
# list

# %%
lista.append("o lolol") #adicionar elemento na lista

# %%
print(lista)
print(lista[3])
# Out:
# [12, 'pachevo', 1.55, 'o lolol']
# o lolol

# %% [markdown]
# ##* Tupla

# %%
tuplsa=(33,"ostvato", 6.58)

# %%
type(tuplsa)
# Out:
# tuple

# %%
tupla.append("nelson")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-07eaf19ab67a> in <cell line: 0>()
# ----> 1 tupla.append("nelson")
#
# NameError: name 'tupla' is not defined

# %%
print(tuplsa)
print(tuplsa[2])
# Out:
# (33, 'ostvato', 6.58)
# 6.58

# %% [markdown]
# ##* Dicionário

# %%
Dic={"nome":"alfredo", "cidade":"sao jose","idade":22}

# %%
type(Dic)
# Out:
# dict

# %%
print(Dic)
# Out:
# {'nome': 'alfredo', 'cidade': 'sao jose', 'idade': 22}

# %%
print(Dic["nome"])
# Out:
# alfredo

# %%
Dic["sobrenome"] ="Souza"#Adicionar elemento num aquivo tipo dicionario

# %%
print(Dic)
# Out:
# {'nome': 'alfredo', 'cidade': 'sao jose', 'idade': 22, 'sobrenome': 'Souza'}
