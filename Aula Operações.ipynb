# %% [markdown]
# #Operaçãos

# %%
#adição
12+3
# Out:
# 15

# %%
#Subtrasão
12-3
# Out:
# 9

# %%
#Multiplicação
12*3
# Out:
# 36

# %%
#Divisão Real
14/3
# Out:
# 4.666666666666667

# %%
#Divisão Inteira
14//3
# Out:
# 4

# %%
#Resto
14%3
# Out:
# 2

# %%
#Potencia
25**13
# Out:
# 1490116119384765625

# %% [markdown]
# ##Relacionais

# %%
#Maior
12>13
12>7
# Out:
# True

# %%
#Menor
12<13
12<7
# Out:
# False

# %%
#Maior ou Igual
12>=13
12>=7
12>=12
# Out:
# True

# %%
#Menor ou Igual
12<=13
12<=7
12<=12
# Out:
# True

# %%
#Igual
12==13
12==7
12==12
# Out:
# True

# %%
#Diferente
12!=13
12!=7
12!=12
# Out:
# False

# %% [markdown]
# ##Logico
# ###Tabela verdade

# %% [markdown]
# #AND(E)

# %%
print(2<3 and 98<99) #v
print(2<3 and 98>99) #F
print(2>3 and 98<99) #f
print(2>3 and 98>99) #F
# Out:
# True
# False
# False
# False

# %% [markdown]
# #OR(OU)

# %%
print(2<3 or 98<99) #v
print(2<3 or 98>99) #v
print(2>3 or 98<99) #v
print(2>3 or 98>99) #F
# Out:
# True
# True
# True
# False

# %% [markdown]
# #Not(Não)

# %%
not 13>7
# Out:
# False

# %%
not 14<15
# Out:
# False
